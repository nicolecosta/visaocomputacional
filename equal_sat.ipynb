# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolecosta/visaocomputacional/blob/main/equal_sat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## EQUALIZAÇÃO SATURAÇÃO

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import sys

img_bgr = cv.imread("lena.png")

if img is None:
    sys.exit("Could not read the image.")
    
cv2_imshow(img_bgr)
img_hsv = cv.cvtColor(img_bgr, cv.COLOR_BGR2HSV)
cv2_imshow(img_hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F8ED005D890>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F8ED005D110>

# %%
H,S,V = cv.split(img_hsv)
cv2_imshow(H)
cv2_imshow(S)
cv2_imshow(V)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F8ED0066750>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F8ED0066750>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F8ED0066910>

# %%
import cv2
from google.colab.patches import cv2_imshow
import sys
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

img = S
if img is None:
    sys.exit("Could not read the image.")
cv2_imshow(img)
plt.hist(img.ravel(),bins=256,range=[0,255]) 
plt.show()

S =cv2.equalizeHist(img)
cv2_imshow(S)
plt.hist(S.ravel(),bins=256,range=[0,255]) 
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F8ED0A0BD10>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F8ECFD05990>

# %%
img_merge = cv.merge((H,S,V))  #junção
cv2_imshow(img_merge)

img_bgr_ = cv.cvtColor(img_merge, cv.COLOR_HSV2BGR)
cv2_imshow(img_bgr_)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F8ED0BA9B50>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F8ED0BA9350>
